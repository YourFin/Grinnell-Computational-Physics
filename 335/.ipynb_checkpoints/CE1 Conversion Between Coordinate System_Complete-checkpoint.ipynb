# %% [markdown]
# # To-Do
# * [Done] Generate a sphere in rectangular coordinates
# * [Done] Plot sphere in 3D
# * Convert rectangular coordinates to spherical
# * Plot again with a spherical projection
# * Convert rectangular coordinates to cylindrical and plot
#
# # Issues
# * Should there be custom functions/a package for the conversion? Currently there is no built-in cylindrical option

# %% [markdown]
# # Computational Exercise 1: Conversion Between Coordinate Systems
#
# In this exercise, we'll be looking at how to convert between different coordinate systems. There are 3 parts to this exercise:
# 1. Plotting a sphere in cartesian coordinates
# 2. Plotting a sphere in circular coordinates
# 3. Plotting a sphere in cylindrical coordinates

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.axes3d import Axes3D
from polar3d import *

# %%
pi = np.pi

r = 1
phi, theta =  np.mgrid[0.0:pi:100j, 0.0:2.0*pi:100j]

"""
Put your code to go from r, phi, and theta to x, y,z here.
We'll talk about np.mgrid in the next lab, but it's important
for making plt.plot_surface work correctly
"""
#/
x = np.sin(phi) * np.cos(theta)
y = np.sin(phi) * np.sin(theta)
z = np.cos(phi)
#/

fig = plt.figure(figsize=plt.figaspect(1)*4)  # Square figure
ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(x, y, z)
plt.show()

# %%
"""
In this cell, convert your x, y, and z from the last cell into
r, phi, and theta. The function spherical3d() will handle generating
the figure, since there is no built-in python function for that
"""

#/
#Generate a sphere in spherical coordinates
r = np.ones(50)
phi = np.linspace(0, 2*pi, 50)
theta = np.linspace(0, pi, 50)
phi, theta= np.meshgrid(phi, theta)


r = np.sqrt(x**2 + y**2 + z**2)
phi = np.arccos(z/r)
theta = np.arctan(y/x)
#/

spherical3d(r, theta, phi)
plt.show()
# Out:
# [[0.         0.         0.         ... 0.         0.         0.        ]
#  [0.03173326 0.03173326 0.03173326 ... 0.03173326 0.03173326 0.03173326]
#  [0.06346652 0.06346652 0.06346652 ... 0.06346652 0.06346652 0.06346652]
#  ...
#  [3.07812614 3.07812614 3.07812614 ... 3.07812614 3.07812614 3.07812614]
#  [3.10985939 3.10985939 3.10985939 ... 3.10985939 3.10985939 3.10985939]
#  [3.14159265 3.14159265 3.14159265 ... 3.14159265 3.14159265 3.14159265]]
# <ipython-input-7-0ee2c73cdb9c>:18: RuntimeWarning: invalid value encountered in true_divide
#   theta = np.arctan(y/x)
